# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
Marvel=pd.read_csv(r"D:\Anamika\kaam\Python\marvel_demo_stats_powers.csv")
marvel=Marvel[['Name','Alignment_x','Intelligence_x','Strength','Speed','Durability_x','Power','Combat','Total']]
marvel.head()
# Out:
#             Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 0         A-Bomb        good            38.0     100.0   17.0          80.0
# 1    Abomination         bad            63.0      80.0   53.0          90.0
# 2        Abraxas         bad            88.0     100.0   83.0          99.0
# 3  Absorbing Man         bad             NaN       NaN    NaN           NaN
# 4       Agent 13        good             NaN       NaN    NaN           NaN
#
#    Power  Combat  Total
# 0   17.0    64.0  316.0
# 1   55.0    95.0  436.0
# 2  100.0    56.0  526.0
# 3    NaN     NaN    NaN
# 4    NaN     NaN    NaN

# %%
marvel.shape
# Out:
# (382, 9)

# %%
marvel['Alignment_x'].value_counts()
# Out:
# good       254
# bad        114
# neutral     11
# -            3
# Name: Alignment_x, dtype: int64

# %%
good=marvel[marvel['Alignment_x']=='good']

# %%
good.sort_values(by='Speed',ascending=False).head()
# Out:
#                Name Alignment_x  Intelligence_x  Strength  Speed  \
# 183  Jack of Hearts        good            63.0      55.0  100.0
# 43       Black Bolt        good            75.0      67.0  100.0
# 321        Stardust        good            88.0      85.0  100.0
# 252         Nova II        good            38.0      60.0  100.0
# 270     Quicksilver        good            63.0      28.0  100.0
#
#      Durability_x  Power  Combat  Total
# 183          30.0   70.0    30.0  348.0
# 43           84.0  100.0    56.0  482.0
# 321         110.0  100.0    85.0  568.0
# 252         100.0  100.0    25.0  423.0
# 270          60.0   57.0    56.0  364.0

# %%
good.sort_values(by='Power',ascending=False).head()
# Out:
#            Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 252     Nova II        good            38.0      60.0  100.0         100.0
# 177      Iceman        good            63.0      32.0   53.0         100.0
# 43   Black Bolt        good            75.0      67.0  100.0          84.0
# 260     Phoenix        good           100.0      80.0   67.0         100.0
# 35     Beyonder        good            88.0     100.0   23.0         100.0
#
#      Power  Combat  Total
# 252  100.0    25.0  423.0
# 177  100.0    64.0  412.0
# 43   100.0    56.0  482.0
# 260  100.0    70.0  517.0
# 35   100.0    56.0  467.0

# %%
good_max_poweful=good[good['Power']==100]

# %%
good_max_poweful.head()
# Out:
#                Name Alignment_x  Intelligence_x  Strength  Speed  \
# 34    Beta Ray Bill        good            63.0      80.0   35.0
# 35         Beyonder        good            88.0     100.0   23.0
# 43       Black Bolt        good            75.0      67.0  100.0
# 73            Cable        good            88.0      48.0   23.0
# 115  Doctor Strange        good           100.0      10.0   12.0
#
#      Durability_x  Power  Combat  Total
# 34           95.0  100.0    84.0  457.0
# 35          100.0  100.0    56.0  467.0
# 43           84.0  100.0    56.0  482.0
# 73           56.0  100.0    80.0  395.0
# 115          84.0  100.0    60.0  366.0

# %%
good_max_power=good.sort_values(by='Total',ascending=False)

# %%
good_max_power.head()
# Out:
#           Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 321   Stardust        good            88.0      85.0  100.0         110.0
# 330       Thor        good            69.0     100.0   92.0         100.0
# 251       Nova        good           100.0      85.0   67.0         101.0
# 184  Jean Grey        good           100.0      80.0   67.0         100.0
# 260    Phoenix        good           100.0      80.0   67.0         100.0
#
#      Power  Combat  Total
# 321  100.0    85.0  568.0
# 330  100.0    85.0  546.0
# 251  100.0    85.0  538.0
# 184  100.0    70.0  517.0
# 260  100.0    70.0  517.0

# %%
plt.figure(figsize=(8,5))
plt.bar(list(good_max_power['Name'])[0:5],list(good_max_power['Total'])[0:5], color='g')
plt.show()

# %%
bad=marvel[marvel['Alignment_x']=='bad']

# %%
bad.head()
# Out:
#             Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 1    Abomination         bad            63.0      80.0   53.0          90.0
# 2        Abraxas         bad            88.0     100.0   83.0          99.0
# 3  Absorbing Man         bad             NaN       NaN    NaN           NaN
# 7     Air-Walker         bad            50.0      85.0  100.0          85.0
# 8           Ajax         bad             NaN       NaN    NaN           NaN
#
#    Power  Combat  Total
# 1   55.0    95.0  436.0
# 2  100.0    56.0  526.0
# 3    NaN     NaN    NaN
# 7  100.0    40.0  460.0
# 8    NaN     NaN    NaN

# %%
bad.sort_values(by='Speed',ascending=False).head()
# Out:
#               Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 7       Air-Walker         bad            50.0      85.0  100.0          85.0
# 129  Fallen One II         bad            88.0      85.0   83.0         100.0
# 120            Ego         bad            88.0      80.0   83.0          99.0
# 118       Dormammu         bad            88.0      95.0   83.0         100.0
# 2          Abraxas         bad            88.0     100.0   83.0          99.0
#
#      Power  Combat  Total
# 7    100.0    40.0  460.0
# 129  100.0    56.0  512.0
# 120   71.0    28.0  449.0
# 118  100.0    80.0  546.0
# 2    100.0    56.0  526.0

# %%
bad.sort_values(by='Intelligence_x',ascending=False).head()
# Out:
#             Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 218     Mandarin         bad           100.0      28.0   23.0          28.0
# 17    Apocalypse         bad           100.0     100.0   33.0         100.0
# 194         Kang         bad           100.0      48.0   58.0          70.0
# 112  Doctor Doom         bad           100.0      32.0   20.0         100.0
# 339     Tinkerer         bad           100.0      10.0   23.0          14.0
#
#      Power  Combat  Total
# 218   99.0    95.0  373.0
# 17   100.0    60.0  493.0
# 194   71.0    70.0  417.0
# 112   93.0    84.0  429.0
# 339   10.0    14.0  171.0

# %%
bad.sort_values(by='Total',ascending=False).head()
# Out:
#               Name Alignment_x  Intelligence_x  Strength  Speed  Durability_x  \
# 118       Dormammu         bad            88.0      95.0   83.0         100.0
# 215          Magus         bad            88.0     100.0   70.0          99.0
# 2          Abraxas         bad            88.0     100.0   83.0          99.0
# 129  Fallen One II         bad            88.0      85.0   83.0         100.0
# 256      Onslaught         bad            88.0      85.0   47.0         100.0
#
#      Power  Combat  Total
# 118  100.0    80.0  546.0
# 215  100.0    74.0  531.0
# 2    100.0    56.0  526.0
# 129  100.0    56.0  512.0
# 256  100.0    85.0  505.0

# %%
plt.figure(figsize=(8,5))
plt.hist(good['Speed'])
plt.title("Didtribution Of Superheros")
plt.xlabel("Speed")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(bad['Combat'])
plt.title("Didtribution Of SuperVilans")
plt.xlabel("Combat")
plt.show()
